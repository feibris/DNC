# %% [markdown]
# <a href="https://colab.research.google.com/github/feibris/DNC/blob/Python/desafio4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar o que precisa, ler o arquivo:

import pandas as pd
base = pd.read_csv('MKT.csv')

import seaborn as sns

import matplotlib.pyplot as plt

# %%
# vendo os primeiros registros:
base.head()
# Out:
#    youtube  facebook  newspaper  sales
# 0    84.72     19.20      48.96  12.60
# 1   351.48     33.96      51.84  25.68
# 2   135.48     20.88      46.32  14.28
# 3   116.64      1.80      36.00  11.52
# 4   318.72     24.00       0.36  20.88

# %%
#vendo as informaçoes das colunas:
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   youtube    171 non-null    float64
#  1   facebook   171 non-null    float64
#  2   newspaper  171 non-null    float64
#  3   sales      171 non-null    float64
# dtypes: float64(4)
# memory usage: 5.5 KB

# %%
#vendo os tipos e outros informaçoes
base.describe()
# Out:
#           youtube    facebook   newspaper       sales
# count  171.000000  171.000000  171.000000  171.000000
# mean   178.021053   27.671579   35.240000   16.922807
# std    102.449597   17.913532   24.902918    6.314608
# min      0.840000    0.000000    0.360000    1.920000
# 25%     91.080000   11.700000   13.740000   12.540000
# 50%    179.760000   26.760000   31.080000   15.480000
# 75%    262.980000   43.680000   50.880000   20.820000
# max    355.680000   59.520000  121.080000   32.400000

# %%
# importei la no inicio o (import seaborn as sns)
#vendo a distribuição dos dados

sns.pairplot(base, x_vars=['youtube', 'facebook', 'newspaper'], y_vars=['sales'])

# %%
# feito a imporatacao do (import matplotlib.pyplot as plt) la no inicio
#vendo melhor os dados separados em colunas

plt.subplot(2,2,1)
sns.histplot(base["youtube"]).set(title="Youtube")
plt.subplot(2,2,2)
sns.histplot(base["facebook"]).set(title="Facebook")
plt.subplot(2,2,3)
sns.histplot(base["newspaper"]).set(title="Newspaper")
plt.tight_layout()

# %%
# criando o x e o y com os dados para  o treinos
X = base[['youtube', 'facebook', 'newspaper']]

Y = base[['sales']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.7,  test_size = 0.2,  random_state =42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (119, 3)
# (35, 3)
# (119, 1)
# (35, 1)

# %%
# a construção do modelo
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
# vamos calcualr o predição

#predições no conjunto de teste
y_pred = lm.predict(X_test)

from sklearn.metrics import r2_score

# Avaliando
r = r2_score(Y_test, y_pred)

#vendo o score
print("Coeficiente r_quadrado:",r )
# Out:
# Coeficiente r_quadrado: 0.8793143122026136

# %%
# ja fui no inicio  e importei o (import matplotlib.pyplot as plt)

tabela = pd.DataFrame()
tabela["o Teste"] = Y_test
tabela["Prev. Regressão Linear"] = y_pred
sns.lineplot(data=tabela)
# Out:
# <Axes: >
